# %%
import googlemaps
import pandas as pd
import time

# Google Places APIのAPIキーを設定
API_KEY = 'AIzaSyA4TEv7MSQCBwmUsC8bQK-YKQP0RtLdQDE'
gmaps = googlemaps.Client(key=API_KEY)

# 10地点の緯度経度情報をリストに格納
locations = [
    ('梅田', 34.7005588, 135.4957339),
    ('西宮北口', 34.7459022, 135.356664),
    ('なんば', 34.6670979, 135.5003424),
    ('天王寺', 34.6473102, 135.513869),
    ('千里中央', 34.8074603, 135.4952222),
    ('十三', 34.720213, 135.48206),
    ('江坂', 34.758768, 135.4970962),
    ('心斎橋', 34.6747701, 135.5003959),
    ('本町', 34.6820067, 135.4988295),
    ('吹田', 34.7630033, 135.5238259),
]

# 結果を格納するためのリスト
temples_info = []

# 各地点に対して寺情報を取得
for name, lat, lng in locations:
    place_results = gmaps.places_nearby(location=f'{lat},{lng}', radius=1000, keyword='寺', language='ja')
    results = place_results['results']

    for result in results:
        temple_name = result['name']
        rating = result.get('rating', None)
        user_ratings_total = result.get('user_ratings_total', None)
        location = result['geometry']['location']

        # 必要な情報を辞書としてリストに追加
        temples_info.append({
            '地点名': name,
            '寺名': temple_name,
            '評価': rating,
            '口コミ数': user_ratings_total,
            '緯度': location['lat'],
            '経度': location['lng']
        })
        
        time.sleep(1)

# リストをPandas DataFrameに変換
df_temples = pd.DataFrame(temples_info)

# %%
df_temples.head()
# Out:
#   地点名   寺名   評価  口コミ数         緯度          経度
# 0  梅田  太融寺  4.0   835  34.701823  135.504104
# 1  梅田  地蔵寺  4.0     7  34.696292  135.488300
# 2  梅田  龍渕寺  4.0     7  34.699956  135.505633
# 3  梅田  圓勝寺  3.7     6  34.701619  135.485248
# 4  梅田  浄祐寺  3.9    14  34.696595  135.490869

# %%
df_temples.to_csv('temple_info1.csv', index=False)
