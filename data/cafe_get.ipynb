# %%
pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/suzukiyuta/opt/anaconda3/lib/python3.9/site-packages (from googlemaps) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/suzukiyuta/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/suzukiyuta/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/suzukiyuta/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/suzukiyuta/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40717 sha256=e4e582c6f17ecbd3b2c9bf0531466a9bd88f6127de3410123ff45535b85b63cf
#   Stored in directory: /Users/suzukiyuta/Library/Caches/pip/wheels/3b/f0/d7/aefb9f48508f7bcaa748b872b7828dd39982cf98897e0fd45b
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import json
import pprint
import time
import pandas as pd

API_KEY = 'AIzaSyA4TEv7MSQCBwmUsC8bQK-YKQP0RtLdQDE'
gmaps = googlemaps.Client(key=API_KEY)
place_results = gmaps.places_nearby(location='34.6924107,135.5016849', radius=20000, keyword='カフェ', language='ja')
results = place_results['results']

# 結果を格納するためのリスト
cafes_info = []

for result in results:
    name = result['name']
    rating = result.get('rating', None)
    user_ratings_total = result.get('user_ratings_total', None)
    location = result['geometry']['location']

    # 必要な情報を辞書としてリストに追加
    cafes_info.append({
        '店名': name,
        '評価': rating,
        '口コミ数': user_ratings_total,
        '緯度': location['lat'],
        '経度': location['lng']
    })

# リストをPandas DataFrameに
df = pd.DataFrame(cafes_info)

df
# Out:
#                            店名   評価  口コミ数         緯度          経度
# 0                     こ・ふんカフェ  4.0   150  34.565065  135.491862
# 1      CAFÉ TOKIONA（カフェ トキオナ）  4.2   485  34.694589  135.511796
# 2                    珈乃香 川西本店  3.9   496  34.808651  135.411646
# 3                      カフェはたち  4.1   245  34.541646  135.557855
# 4                   カフェ オーガスタ  4.4    56  34.712727  135.546264
# 5                       MRカフェ  4.3    49  34.579728  135.468786
# 6   Cafe funchana カフェ ファンチャーナ  4.3   191  34.588436  135.686223
# 7                    カフェぶいえいと  4.3   431  34.814753  135.562372
# 8              こふん前cafe IROHA  4.0   139  34.559322  135.486475
# 9                    カフェ ヴェーク  4.6    94  34.672487  135.490394
# 10             ナカザキカフェ 中崎町カフェ  4.3   116  34.708280  135.504107
# 11         MiLDA Cafe ミルダ カフェ  4.6    86  34.777152  135.414407
# 12            吹田 カフェ 喫茶店 ほっぷっ  4.7    43  34.761069  135.526571
# 13               カフェレステライ・オシノ  3.0    83  34.736958  135.592449
# 14                カフェ エデン 江坂店  4.1   266  34.756469  135.494942
# 15                 ブック＆カフェ喫茶去  4.7    38  34.684965  135.490125
# 16                     カフェ・山歩  4.5    34  34.726962  135.569187
# 17                    カフェレードル  4.6   216  34.817838  135.563812
# 18        カイゲンカフェ kaigen cafe  4.0   150  34.684120  135.492624
# 19                  カフェ フロリアン  3.4    33  34.672626  135.495590

# %%
import googlemaps
import pandas as pd
import time

# Google Places APIのAPIキーを設定
API_KEY = 'AIzaSyA4TEv7MSQCBwmUsC8bQK-YKQP0RtLdQDE'
gmaps = googlemaps.Client(key=API_KEY)

# 10地点の緯度経度情報をリストに格納
locations = [
    ('梅田', 34.7005588, 135.4957339),
    ('西宮北口', 34.7459022, 135.356664),
    ('なんば', 34.6670979, 135.5003424),
    ('天王寺', 34.6473102, 135.513869),
    ('千里中央', 34.8074603, 135.4952222),
    ('十三', 34.720213, 135.48206),
    ('江坂', 34.758768, 135.4970962),
    ('心斎橋', 34.6747701, 135.5003959),
    ('本町', 34.6820067, 135.4988295),
    ('吹田', 34.7630033, 135.5238259),
]

# 結果を格納するためのリスト
cafes_info = []

# 各地点に対してカフェ情報を取得
for name, lat, lng in locations:
    place_results = gmaps.places_nearby(location=f'{lat},{lng}', radius=1000, keyword='カフェ', language='ja')
    results = place_results['results']

    for result in results:
        cafe_name = result['name']
        rating = result.get('rating', None)
        user_ratings_total = result.get('user_ratings_total', None)
        location = result['geometry']['location']

        # 必要な情報を辞書としてリストに追加
        cafes_info.append({
            '地点名': name,
            'カフェ名': cafe_name,
            '評価': rating,
            '口コミ数': user_ratings_total,
            '緯度': location['lat'],
            '経度': location['lng']
        })
        
        time.sleep(1)

# リストをPandas DataFrameに変換
df = pd.DataFrame(cafes_info)

# %%
df.to_csv('cafe_info1.csv', index=False)
