# %%
import googlemaps
import pandas as pd
import time

# Google Places APIのAPIキーを設定
API_KEY = 'AIzaSyA4TEv7MSQCBwmUsC8bQK-YKQP0RtLdQDE'
gmaps = googlemaps.Client(key=API_KEY)

# 10地点の緯度経度情報をリストに格納
locations = [
    ('梅田', 34.7005588, 135.4957339),
    ('西宮北口', 34.7459022, 135.356664),
    ('なんば', 34.6670979, 135.5003424),
    ('天王寺', 34.6473102, 135.513869),
    ('千里中央', 34.8074603, 135.4952222),
    ('十三', 34.720213, 135.48206),
    ('江坂', 34.758768, 135.4970962),
    ('心斎橋', 34.6747701, 135.5003959),
    ('本町', 34.6820067, 135.4988295),
    ('吹田', 34.7630033, 135.5238259),
]

# 結果を格納するためのリスト
parks_info = []

# 各地点に対してカフェ情報を取得
for name, lat, lng in locations:
    place_results = gmaps.places_nearby(location=f'{lat},{lng}', radius=1000, keyword='公園', language='ja')
    results = place_results['results']

    for result in results:
        park_name = result['name']
        rating = result.get('rating', None)
        user_ratings_total = result.get('user_ratings_total', None)
        location = result['geometry']['location']

        # 必要な情報を辞書としてリストに追加
        parks_info.append({
            '地点名': name,
            '公園名': park_name,
            '評価': rating,
            '口コミ数': user_ratings_total,
            '緯度': location['lat'],
            '経度': location['lng']
        })
        
        time.sleep(1)

# リストをPandas DataFrameに変換
df_parks = pd.DataFrame(parks_info)

# %%
df_parks.head()
# Out:
#   地点名    公園名   評価  口コミ数         緯度          経度
# 0  梅田  大淀北公園  3.5    46  34.707963  135.486687
# 1  梅田  大淀中公園  3.5    63  34.705022  135.488724
# 2  梅田  大淀南公園  3.2    72  34.703493  135.487933
# 3  梅田  上福島公園  3.7    64  34.698336  135.484847
# 4  梅田  中津南公園  3.5    68  34.706128  135.491404

# %%
df_parks.to_csv('parks_info1.csv', index=False)
